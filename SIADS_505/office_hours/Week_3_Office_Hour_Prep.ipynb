# %% [markdown]
# # Office Hour Week 3

# %%
# The office hour will start in 5 minutes. 

# During the office hour, you can clarify and ask questions about course content.
# You can also talk about problems regarding your reading, code, etc. 
# I am glad to explain and help. Let us begin soon!

# %% [markdown]
# To be able to run the code, it's recommended to put this demo into /resources directory.

# %% [markdown]
# # Jupyter Notebook vs Spyder vs Python IDLE vs Pycharm

# %%
# pd.read_excel(na_values = "...")

# %%
# Let's first import numpy, pandas, matplotlib, scipy.stats 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Let's import the president data
presidents = pd.read_csv("datasets/presidents.csv")
# Let's import the census.csv
census = pd.read_csv("datasets/census.csv")

# %%
# and take a look for the first few rows
presidents.head()

# %%
# and take a look for the first few tows
census.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %% [markdown]
# * pandorable Pandas chain
# * Groupby()
# * merge()
# * pivot_table()
# * crosstab()
# * unstack()
# * pd.melt()
# * agg()

# %% [markdown]
# * nlargest()
# * idxmax()
#
# The nlargest() function is used to get the first n rows ordered by columns in descending order. The columns that are not specified are returned as well, but not used for ordering.
#
# Syntax:
#
# DataFrame.nlargest(self, n, columns, keep='first')

# %% [markdown]
# Let us learn the describe() function!
#
# * The describe() function is used to generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.
# * Syntax: DataFrame.describe(self, percentiles=None, include=None, exclude=None)

# %%
census.describe()
# Out:
#             SUMLEV       REGION     DIVISION        STATE       COUNTY  \
# count  3193.000000  3193.000000  3193.000000  3193.000000  3193.000000
# mean     49.840276     2.668650     5.191356    30.259004   101.918572
# std       1.253884     0.807513     1.973991    15.153897   107.626583
# min      40.000000     1.000000     1.000000     1.000000     0.000000
# 25%      50.000000     2.000000     4.000000    18.000000    33.000000
# 50%      50.000000     3.000000     5.000000    29.000000    77.000000
# 75%      50.000000     3.000000     7.000000    45.000000   133.000000
# max      50.000000     4.000000     9.000000    56.000000   840.000000
#
#        CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# count   3.193000e+03       3.193000e+03     3.193000e+03     3.193000e+03
# mean    1.933871e+05       1.933969e+05     1.937657e+05     1.952514e+05
# std     1.176201e+06       1.176244e+06     1.178710e+06     1.189648e+06
# ...

# %% [markdown]
# You can see there are 3193 rows in the census dataset. Doing a bit sleuthing on 'CENSUS2010POP' which is the census population in 2010, you can see
#
# * mean: the average census population in 2010 among 3193 b

# %% [markdown]
# Fun fact see: https://www.census.gov/quickfacts/fact/table/US/PST045219

# %%
type(census.groupby('STNAME'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
census.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011',
#        'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015',
#        'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
#        'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013',
#        'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011',
#        'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015',
#        'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012',
#        'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015',
#        'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012',
#        'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010',
# ...

# %%
census[['RDOMESTICMIG2011',
       'RDOMESTICMIG2012', 'RDOMESTICMIG2013', 'RDOMESTICMIG2014',
       'RDOMESTICMIG2015']]
# Out:
#       RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0             0.002295         -0.193196          0.381066          0.582002
# 1             7.242091         -2.915927         -3.012349          2.265971
# 2            14.832960         17.647293         21.845705         19.243287
# 3            -4.728132         -2.500690         -7.056824         -3.904217
# 4            -5.527043         -5.068871         -6.201001         -0.177537
# ...                ...               ...               ...               ...
# 3188          1.072643         16.243199         -5.339774        -14.252889
# 3189         -1.589565          0.972695         19.525929         14.143021
# 3190        -17.755986         -4.916350         -6.902954        -14.215862
# 3191        -11.637475         -0.827815         -2.013502        -17.781491
# 3192        -11.752361         -8.040059         12.372583          1.533635
#
#       RDOMESTICMIG2015
# ...

# %%
#census.groupby('STNAME').agg('max')['CENSUS2010POP']
#census.groupby('STNAME').agg(['min', 'mean', 'max'])['CENSUS2010POP']

# %%
# Same result
#census.groupby('STNAME').CENSUS2010POP.agg(['min', 'mean', 'max'])

# %%
# Different aggregations per column
#census.groupby('STNAME').agg({'CENSUS2010POP': ['min', 'mean', 'max'], 'RDOMESTICMIG2015': ['mean', 'var']})

# %% [markdown]
# * time-series()
# * get_dummies()
# https://towardsdatascience.com/the-dummys-guide-to-creating-dummy-variables-f21faddb1d40
# https://towardsdatascience.com/what-is-one-hot-encoding-and-how-to-use-pandas-get-dummies-function-922eb9bd4970
# * Date/Time functions

# %% [markdown]
# * https://stackoverflow.com/questions/35029083/gt-operator-in-pandas-dataframe
# * https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html
# * https://www.tutorialspoint.com/python_pandas/python_pandas_panel.htm

# %% [markdown]
# * https://distill.pub/

# %%
census['REGION'].value_counts()
# Out:
# 3    1439
# 2    1067
# 4     461
# 1     226
# Name: REGION, dtype: int64

# %%
census['DIVISION'].value_counts()
# Out:
# 4    625
# 5    597
# 7    474
# 3    442
# 6    368
# 8    289
# 9    172
# 2    153
# 1     73
# Name: DIVISION, dtype: int64

# %%
census['DIVISION'].value_counts(normalize = True)
# Out:
# 4    0.195741
# 5    0.186972
# 7    0.148450
# 3    0.138428
# 6    0.115252
# 8    0.090510
# 9    0.053868
# 2    0.047917
# 1    0.022863
# Name: DIVISION, dtype: float64

# %%
state_group = census.groupby('STNAME')
state_group.get_group('Michigan')
#['ESTIMATESBASE2010'].value_counts(normalize = True)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME           CTYNAME  \
# 1253      40       2         3     26       0  Michigan          Michigan
# 1254      50       2         3     26       1  Michigan     Alcona County
# 1255      50       2         3     26       3  Michigan      Alger County
# 1256      50       2         3     26       5  Michigan    Allegan County
# 1257      50       2         3     26       7  Michigan     Alpena County
# ...      ...     ...       ...    ...     ...       ...               ...
# 1332      50       2         3     26     157  Michigan    Tuscola County
# 1333      50       2         3     26     159  Michigan  Van Buren County
# 1334      50       2         3     26     161  Michigan  Washtenaw County
# 1335      50       2         3     26     163  Michigan      Wayne County
# 1336      50       2         3     26     165  Michigan    Wexford County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
state_group['POPESTIMATE2010'].value_counts()
# Out:
# STNAME   POPESTIMATE2010
# Alabama  9001               1
#          10540              1
#          10887              1
#          11275              1
#          11557              1
#                            ..
# Wyoming  43593              1
#          46244              1
#          75472              1
#          92271              1
#          564516             1
# Name: POPESTIMATE2010, Length: 3188, dtype: int64

# %%
# groupby('col').get_group('value')

# %%
state_group['POPESTIMATE2010'].median().loc['Michigan']
# Out:
# 40512.5

# %%
state_group.get_group('Michigan')[20:40]
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME  \
# 1273      50       2         3     26      39  Michigan
# 1274      50       2         3     26      41  Michigan
# 1275      50       2         3     26      43  Michigan
# 1276      50       2         3     26      45  Michigan
# 1277      50       2         3     26      47  Michigan
# 1278      50       2         3     26      49  Michigan
# 1279      50       2         3     26      51  Michigan
# 1280      50       2         3     26      53  Michigan
# 1281      50       2         3     26      55  Michigan
# 1282      50       2         3     26      57  Michigan
# 1283      50       2         3     26      59  Michigan
# 1284      50       2         3     26      61  Michigan
# 1285      50       2         3     26      63  Michigan
# 1286      50       2         3     26      65  Michigan
# 1287      50       2         3     26      67  Michigan
# 1288      50       2         3     26      69  Michigan
# ...

# %%
# Target nanfill

# %%
# Replace value-by-value approach
# replace(1, 100)
# Or passing a list of values on both sides
# replace([], [])
# Or passing a regex by adding regex = True option
# replace(to_replace = "", value = "", regex = True)
# str.replace("", "")

# %% [markdown]
# # Pivot Table

# %% [markdown]
# * values option: We pass the column values to be compared against
#
# * index option:
#
# * columns option:
#
# * You can pass a named parameter, aggfunc, which is a list of the different functions to apply. Pandas will return you the results using hierarchical column names.
#
# * You can see an summarized values without a given top level column by specifying the margins = True option.

# %%
# Let's take a look
pivot_table(values = '', 
            index = '', 
            columns = '',
            aggfunc = [])

# %%
pivot_table(values = '', 
            index = '', 
            columns = '',
            aggfunc = [], margins = True)

# %% [markdown]
# ## Stacking and unstacking
#
# To recap from the lecture video,
#
# * stack() moves the lowermost column, to the inner most row. Most of the time using stack() will result in your dataset having multi-level indexes
#
# * unstack() is the reverse of stack(). If you used stack() in a data and apply unstack() function, you will see our dataframe restored to its original shape.
#
# What do you think the following code would do?
#
# * stack().stack()
#
# * unstack().unstack()

# %% [markdown]
# Actually, pandas was originally created by Wed McKinney to handle date and time data when he worked as a consultant for hedge funds.

# %%
# Let's bring in pandas and numpy as usual
import pandas as pd
import numpy as np

# %%
grades = pd.read_csv('datasets/class_grades.csv')

# %%
grades.corr()
# Out:
#               Prefix  Assignment  Tutorial   Midterm  TakeHome     Final
# Prefix      1.000000   -0.018342  0.442884 -0.039544 -0.141028  0.090255
# Assignment -0.018342    1.000000  0.392747  0.241723  0.120416  0.295852
# Tutorial    0.442884    0.392747  1.000000  0.134117  0.159028  0.235087
# Midterm    -0.039544    0.241723  0.134117  1.000000 -0.020095  0.723742
# TakeHome   -0.141028    0.120416  0.159028 -0.020095  1.000000 -0.061463
# Final       0.090255    0.295852  0.235087  0.723742 -0.061463  1.000000

# %%
# Remember we used rank() function to create a Rank starting from the student with the highest final score
grades['Rank'] = grades['Final'].rank(method = 'max', na_option = 'bottom', ascending = False)
grades.sort_values("Rank", inplace = True)

# %%
bins = [0, 50, 60, 70, 80, 90, 100, 110]
grade_letters = ['F', 'E', 'D', 'C', 'B', 'A', 'A+']
pd.cut(grades['Final'],bins, labels = grade_letters)
# Out:
# 68     A+
# 33     A+
# 75     A+
# 48     A+
# 63     A+
#      ...
# 22      F
# 56      F
# 60    NaN
# 20    NaN
# 38    NaN
# Name: Final, Length: 99, dtype: category
# Categories (7, object): [F < E < D < C < B < A < A+]

# %%
grades['Final_Grade'] = pd.cut(grades['Final'], bins, labels = grade_letters)
grades
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome   Final  Rank Final_Grade
# 68       7      100.83    105.57   101.25    104.44  108.89   1.0          A+
# 33       7       98.58     91.03   101.25    104.26  107.78   2.0          A+
# 75       7       93.83       NaN   106.25     94.44  102.78   3.0          A+
# 48       8       95.90     99.99    95.62    105.56  102.22   4.0          A+
# 63       7       95.00     94.36    90.62    100.93  101.11   5.0          A+
# ..     ...         ...       ...      ...       ...     ...   ...         ...
# 22       8       63.78     76.21    39.38     42.22   34.44  95.0           F
# 56       8       87.93    106.53    37.50     97.41   28.06  96.0           F
# 60       8       71.79    102.87    41.88     24.77     NaN  99.0         NaN
# 20       8       63.40     86.21    63.12     72.78     NaN  99.0         NaN
# 38       6       90.74     89.64    61.25     90.00     NaN  99.0         NaN
#
# [99 rows x 8 columns]

# %%
#census.columns
pd.qcut(census['GQESTIMATES2010'],4)

# %%
#census
pd.cut(census['CENSUS2010POP'],4)
# Out:
# 0       (71404.0, 37253956.0]
# 1          (26424.0, 71404.0]
# 2       (71404.0, 37253956.0]
# 3          (26424.0, 71404.0]
# 4          (11299.0, 26424.0]
#                 ...
# 3188       (26424.0, 71404.0]
# 3189       (11299.0, 26424.0]
# 3190       (11299.0, 26424.0]
# 3191        (81.999, 11299.0]
# 3192        (81.999, 11299.0]
# Name: CENSUS2010POP, Length: 3193, dtype: category
# Categories (4, interval[float64]): [(81.999, 11299.0] < (11299.0, 26424.0] < (26424.0, 71404.0] < (71404.0, 37253956.0]]

# %%
pd.qcut(census['CENSUS2010POP'], [0, 0.1, 0.5, 0.9, 1.])
# Out:
# 0       (238281.6, 37253956.0]
# 1          (26424.0, 238281.6]
# 2          (26424.0, 238281.6]
# 3          (26424.0, 238281.6]
# 4            (5252.6, 26424.0]
#                  ...
# 3188       (26424.0, 238281.6]
# 3189         (5252.6, 26424.0]
# 3190         (5252.6, 26424.0]
# 3191         (5252.6, 26424.0]
# 3192         (5252.6, 26424.0]
# Name: CENSUS2010POP, Length: 3193, dtype: category
# Categories (4, interval[float64]): [(81.999, 5252.6] < (5252.6, 26424.0] < (26424.0, 238281.6] < (238281.6, 37253956.0]]

# %% [markdown]
# * To select a random subset without replacement, you can use the sample method on Series and DataFrame
#
# * To generate a sample with replacement (to allow repeat choices), pass replace=True to sample

# %%
census.sample(1000)
census.sample(500, replace = True)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY          STNAME  \
# 2796      50       3         7     48     459           Texas
# 1148      50       3         7     22      33       Louisiana
# 3004      50       4         9     53       7      Washington
# 1930      50       3         5     37      13  North Carolina
# 578       50       4         8     16      29           Idaho
# ...      ...     ...       ...    ...     ...             ...
# 1059      50       3         6     21      97        Kentucky
# 1564      50       2         4     29     111        Missouri
# 1344      50       2         4     27      13       Minnesota
# 231       50       4         9      6      81      California
# 1962      50       3         5     37      77  North Carolina
#
#                       CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# 2796            Upshur County          39309              39316
# 1148  East Baton Rouge Parish         440171             440178
# ...

# %% [markdown]
# A recipe you may find useful is computing a dict of the data pieces as a one-liner:

# %%
dict(list(census.groupby('CENSUS2010POP')))
# Out:
# {82:       SUMLEV  REGION  DIVISION  STATE  COUNTY STNAME        CTYNAME  \
#  2717      50       3         7     48     301  Texas  Loving County
#
#        CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
#  2717             82                 82               83  ...
#
#        RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
#  2717        101.123596       -147.727273        239.130435       -178.947368
#
#        RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  \
#  2717        281.407035   101.123596  -147.727273   239.130435  -178.947368
#
#        RNETMIG2015
#  2717   281.407035
#
#  [1 rows x 100 columns],
#  90:      SUMLEV  REGION  DIVISION  STATE  COUNTY  STNAME         CTYNAME  \
#  560      50       4         9     15       5  Hawaii  Kalawao County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
#  560             90                 90               90  ...               0.0
# ...

# %%
census.groupby('CENSUS2010POP')['RDOMESTICMIG2011']

# %%
census['RDOMESTICMIG2011'].groupby(census['CENSUS2010POP'])

# %%
census.groupby(['STNAME', 'CTYNAME'])['RDOMESTICMIG2011'].mean()
# Out:
# STNAME   CTYNAME
# Alabama  Alabama             0.002295
#          Autauga County      7.242091
#          Baldwin County     14.832960
#          Barbour County     -4.728132
#          Bibb County        -5.527043
#                               ...
# Wyoming  Teton County       -1.589565
#          Uinta County      -17.755986
#          Washakie County   -11.637475
#          Weston County     -11.752361
#          Wyoming            -0.381530
# Name: RDOMESTICMIG2011, Length: 3192, dtype: float64

# %%
# Now come back and see the census example
census.reset_index(inplace = True)

# %%
census = census[census['SUMLEV'] == 50]
census.set_index(['STNAME', 'CTYNAME'], inplace = True)
census
# Out:
#                            index  SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County         1      50       3         6      1       1
#         Baldwin County         2      50       3         6      1       3
#         Barbour County         3      50       3         6      1       5
#         Bibb County            4      50       3         6      1       7
#         Blount County          5      50       3         6      1       9
# ...                          ...     ...     ...       ...    ...     ...
# Wyoming Sweetwater County   3188      50       4         8     56      37
#         Teton County        3189      50       4         8     56      39
#         Uinta County        3190      50       4         8     56      41
#         Washakie County     3191      50       4         8     56      43
#         Weston County       3192      50       4         8     56      45
#
# ...

# %%
# Column-Wise and Multiple Function Application
census['Population_Growth'] = census['POPESTIMATE2015'] / census['POPESTIMATE2010']
census['Population_Growth']
# Out:
# <ipython-input-187-d243b1477564>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   census['Population_Growth'] = census['POPESTIMATE2015'] / census['POPESTIMATE2010']
# STNAME   CTYNAME
# Alabama  Autauga County       1.012569
#          Baldwin County       1.111991
#          Barbour County       0.968838
#          Bibb County          0.987840
#          Blount County        1.005229
#                                 ...
# Wyoming  Sweetwater County    1.023696
#          Teton County         1.085834
#          Uinta County         0.986731
#          Washakie County      0.974605
#          Weston County        1.007381
# Name: Population_Growth, Length: 3142, dtype: float64

# %%
census.groupby('STNAME').mean()['Population_Growth']
# Out:
# STNAME
# Alabama                 0.992999
# Alaska                  1.016004
# Arizona                 1.027321
# Arkansas                0.981856
# California              1.017581
# Colorado                1.019329
# Connecticut             0.993515
# Delaware                1.062482
# District of Columbia    1.110889
# Florida                 1.044702
# Georgia                 1.006536
# Hawaii                  1.044546
# Idaho                   1.002045
# Illinois                0.977419
# Indiana                 1.000218
# Iowa                    0.991845
# Kansas                  0.984013
# Kentucky                0.998079
# Louisiana               1.002125
# Maine                   0.990869
# Maryland                1.018007
# Massachusetts           1.026356
# Michigan                0.990611
# Minnesota               0.999559
# Mississippi             0.984745
# Missouri                0.991893
# Montana                 1.022452
# Nebraska                0.986998
# ...

# %%
census.groupby('STNAME').agg(['mean', 'min', 'max', 'var'])['Population_Growth']
# Out:
#                           mean       min       max       var
# STNAME
# Alabama               0.992999  0.886749  1.119388  0.002018
# Alaska                1.016004  0.890220  1.126269  0.002294
# Arizona               1.027321  0.959168  1.142703  0.002243
# Arkansas              0.981856  0.900545  1.119555  0.001864
# California            1.017581  0.899710  1.082220  0.001925
# Colorado              1.019329  0.895683  1.156279  0.003001
# Connecticut           0.993515  0.967487  1.030779  0.000324
# Delaware              1.062482  1.033156  1.089605  0.000800
# District of Columbia  1.110889  1.110889  1.110889       NaN
# Florida               1.044702  0.943551  1.261055  0.003725
# Georgia               1.006536  0.907749  1.207423  0.002465
# Hawaii                1.044546  0.988889  1.067342  0.001042
# Idaho                 1.002045  0.859746  1.103560  0.002024
# Illinois              0.977419  0.825420  1.069833  0.000771
# ...

# %%
census.groupby(level = 'STNAME', axis = 0).count()
# Out:
#                       SUMLEV  REGION  DIVISION  STATE  COUNTY  CENSUS2010POP  \
# STNAME
# Alabama                   68      68        68     68      68             68
# Alaska                    30      30        30     30      30             30
# Arizona                   16      16        16     16      16             16
# Arkansas                  76      76        76     76      76             76
# California                59      59        59     59      59             59
# Colorado                  65      65        65     65      65             65
# Connecticut                9       9         9      9       9              9
# Delaware                   4       4         4      4       4              4
# District of Columbia       2       2         2      2       2              2
# Florida                   68      68        68     68      68             68
# Georgia                  160     160       160    160     160            160
# ...

# %%
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]
bins = [18, 25, 35, 60, 100]
cats = pd.cut(ages, bins)
print(type(cats))
print(type(cats.codes))
cats.categories
pd.value_counts(cats)
# Out:
# <class 'pandas.core.arrays.categorical.Categorical'>
# <class 'numpy.ndarray'>
# (18, 25]     5
# (35, 60]     3
# (25, 35]     3
# (60, 100]    1
# dtype: int64

# %%
# For example, let's create a timestamp using a string 9/1/2019 10:05AM, and here we have our timestamp.
# Timestamp is interchangeable with Python's datetime in most cases.
pd.Timestamp('9/14/2020 2:00PM')
# Out:
# Timestamp('2020-09-14 14:00:00')

# %%
# We can also create a timestamp by passing multiple parameters such as year, month, date, hour,
# minute, separately
pd.Timestamp(2020, 9, 14, 14, 0)
# Out:
# Timestamp('2020-09-14 14:00:00')

# %%
dir(pd.Timestamp(2020, 9, 14, 14, 0))
# Out:
# ['__add__',
#  '__array_priority__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_date_attributes',
#  '_date_repr',
#  '_get_date_name_field',
#  '_get_start_end_field',
#  '_has_time_component',
#  '_repr_base',
#  '_round',
#  '_short_repr',
#  '_time_repr',
#  'asm8',
#  'astimezone',
#  'ceil',
#  'combine',
#  'ctime',
#  'date',
#  'day',
#  'day_name',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'dst',
#  'floor',
#  'fold',
#  'freq',
#  'freqstr',
#  'fromisocalendar',
# ...

# %%
# Timestamp also has some useful attributes, such as isoweekday(), which shows the weekday of the timestamp
# note that 1 represents Monday and 7 represents Sunday
pd.Timestamp(2020, 9, 14, 14, 0).isoweekday()
# Out:
# 1

# %%
# You can extract the specific year, month, day, hour, minute, second for today's timestamp
print("Year: {}\n Month: {}\n Day: {}\n \
Hour: {}\n Minute: {}\n Second: {}".format(pd.Timestamp(2020, 9, 14, 14, 0).year,
                                           pd.Timestamp(2020, 9, 14, 14, 0).month,
                                           pd.Timestamp(2020, 9, 14, 14, 0).day,
                                           pd.Timestamp(2020, 9, 14, 14, 0).hour,
                                           pd.Timestamp(2020, 9, 14, 14, 0).minute,
                                           pd.Timestamp(2020, 9, 14, 14, 0).second))
# Out:
# Year: 2020
#  Month: 9
#  Day: 14
#  Hour: 14
#  Minute: 0
#  Second: 0

# %%
import numpy as np
np.isclose(float(2.2),np.float64(2.2))
# Out:
# True

# %%
np.isclose(int(2), np.float64(2.00))
# Out:
# True

# %% [markdown]
# It used to be that in Korea, bad air quality occurred in spring, and clear air in autumn. Now with growing industries in Asian countries, the air quality is getting worse in Korea in a different seasonality pattern. This data is a log data representing the hourly measurement on several air pollutants in dozens of districts in Seoul.
#
# You can download the data at https://www.kaggle.com/jihyeseo/seoulairreport

# %%
air_pollution = pd.read_csv("SeoulHourlyAvgAirPollution.csv")
air_pollution.head()
# Out:
#            측정일시 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 0  201711242300  강남구         0.038      0.004           0.4       0.005
# 1  201711242200  강남구         0.031      0.008           0.4       0.005
# 2  201711242100  강남구         0.025      0.012           0.4       0.005
# 3  201711242000  강남구         0.033      0.007           0.4       0.005
# 4  201711241900  강남구         0.033      0.008           0.4       0.005
#
#    미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0       16.0        10.0
# 1       17.0         9.0
# 2       18.0        11.0
# 3       21.0        12.0
# 4       20.0        10.0

# %% [markdown]
# You can see that the data gives hourly average concentrations of pollutants taken over a seven day period from November 18th, 2017 to November 24th, 2017.

# %%
air_pollution.shape
# Out:
# (4225, 8)

# %%
titanic = pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.crosstab(titanic.Survived, titanic.Pclass, margins=True, normalize="index")

# %%
pd.crosstab(titanic.Survived, [titanic.Pclass, titanic.Embarked], margins=True)

# %%
pd.crosstab(titanic.Pclass, titanic.Embarked)

# %% [markdown]
# # Magic: Fake Data
#
# * %%fakedata

# %%
from faker import Faker
fake = Faker()

fake.name()
# 'Lucy Cechtelar'
# Out:
# 'Jenna Palmer'

# %%
fake.address()
# '426 Jordy Lodge
#  Cartwrightshire, SC 88120-6700'
# Out:
# '22923 Mccormick Lane Suite 602\nMarioton, CO 36372'

# %%
fake.text()
# 'Sint velit eveniet. Rerum atque repellat voluptatem quia rerum. Numquam excepturi
#  beatae sint laudantium consequatur. Magni occaecati itaque sint et sit tempore. Nesciunt
#  amet quidem. Iusto deleniti cum autem ad quia aperiam.
#  A consectetur quos aliquam. In iste aliquid et aut similique suscipit. Consequatur qui
#  quaerat iste minus hic expedita. Consequuntur error magni et laboriosam. Aut aspernatur
#  voluptatem sit aliquam. Dolores voluptatum est.
#  Aut molestias et maxime. Fugit autem facilis quos vero. Eius quibusdam possimus est.
#  Ea quaerat et quisquam. Deleniti sunt quam. Adipisci consequatur id in occaecati.
#  Et sint et. Ut ducimus quod nemo ab voluptatum.'
# Out:
# 'Prepare read business cover fall certainly chance best. Current sister never computer a think.\nCould role stop question firm plan total door.\nOccur management feel.'

# %% [markdown]
# * Each call to method fake.name() yields a different (random) result. This is because faker forwards faker.Generator.method_name() calls to faker.Generator.format(method_name).
#
# * Each of the generator properties (like name, address, and lorem) are called “fake”. A faker generator has many of them, packaged in “providers”.

# %%
for _ in range(10):
    print(fake.name())
# Out:
# Amy White
# Daniel Bridges
# Jimmy Griffith
# Heather Holland
# Jesse Rice
# Alan Waters
# Justin Johnson
# Tonya Patel
# Stacy Russell
# Jill Stevens

# %%
from faker import Faker
from faker.providers import internet

fake = Faker()
fake.add_provider(internet)

print(fake.ipv4_private())
# Out:
# 192.168.44.153

# %% [markdown]
# ## Localization
#
# faker.Faker can take a locale as an argument, to return localized data. If no localized provider is found, the factory falls back to the default en_US locale.

# %%
from faker import Faker
fake = Faker('it_IT')
for _ in range(10):
    print(fake.name())
# Out:
# Sig.ra Nadia Trebbi
# Eliana Bellucci
# Sebastiano Badoer
# Sig.ra Sophia Barzini
# Ranieri Rossini
# Sig. Ricciotti Fittipaldi
# Carlo Musatti
# Sig.ra Federica Cilea
# Dott. Alina Barzini
# Rolando Chiaramonte-Bocelli

# %% [markdown]
# faker.Faker also supports multiple locales. New in v3.0.0
#
# https://faker.readthedocs.io/en/stable/

# %%
from faker import Faker
fake = Faker(['it_IT', 'en_US', 'ja_JP'])
for _ in range(10):
    print(fake.name())
# Out:
# Nicolò Sokolov
# Tammy Barber
# 鈴木 修平
# Amanda Rivera
# Rita Altera
# 山田 淳
# Dott. Marta Anguissola
# 喜嶋 直樹
# Nicole Williams
# 井高 裕美子

# %%
faker [-h] [--version] [-o output]
      [-l {bg_BG,cs_CZ,...,zh_CN,zh_TW}]
      [-r REPEAT] [-s SEP]
      [-i {package.containing.custom_provider otherpkg.containing.custom_provider}]
      [fake] [fake argument [fake argument ...]]
# Out:
#   File "<ipython-input-111-ba1a0e656453>", line 1
#     faker [-h] [--version] [-o output]
#                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## How to customize the Lorem Provider

# %%
from faker import Faker
fake = Faker()

my_word_list = [
'danish','cheesecake','sugar',
'Lollipop','wafer','Gummies',
'sesame','Jelly','beans',
'pie','bar','Ice','oat' ]

fake.sentence()
# 'Expedita at beatae voluptatibus nulla omnis.'

fake.sentence(ext_word_list=my_word_list)
# 'Oat beans oat Lollipop bar cheesecake.'
# Out:
# 'Cheesecake wafer wafer sesame danish.'

# %% [markdown]
# # Twitch

# %%
# %%fakedata
# people 1000
# ------
# first_name
# last_name
# ssn [1]
#
# purchases 100
# ---------
# isbn10
# ssn [1]
# random_number(3) as price
# Out:
# UsageError: Cell magic `%%fakedata` not found.

# %%
# %%html
# <b>In Son is crazy! He fakes data.</b>
# Out:
# <b>In Son is crazy! He fakes data.</b>

# %%
IPython.core.magic.register_cell_magic?
# Out:
# Object `IPython.core.magic.register_cell_magic` not found.

# %%
from IPython.core.magic import register_cell_magic
from PIL import Image, ImageDraw, ImageFont

@register_cell_magic
def imagine(line, cell):
    myimg = Image.new("L", (200, 100), color = 255)
    scp_font = ImageFont.truetype("./Source_Code_Pro/SourceCodePro-Medium.ttf", size = 30)
    
    dr = ImageDraw.Draw(myimg)
    dr = dr.text((0,0), cell, font = scp_font)
    
    display(myimg)

# %%
from IPython.core.magic import register_cell_magic
from PIL import Image, ImageDraw, ImageFont

@register_cell_magic
def create_dist(line, cell):
    # To do:
    myimg = Image.new("L", (500, 250), color = 255)
    
    scp_font = ImageFont.truetype("./Source_Code_Pro/SourceCodePro-Medium.ttf", size = 48)
    
    # Create drawing object and render our text
    dr = ImageDraw.Draw(myimg)
    dr = dr.text((0,0), cell, font = scp_font)
    
    WHITE_PIXEL_VALUE = 255
    
    # calculate the values along the x-axis of the number of white pixels under 
    # the curve or set the value to None if there is no curve present at a given location
    
    pixels = []
    
    for x in range(img.size[0]):
        num_white_pixels = 0
        for y in range(image.size[1]):
            if img.getpixel((x, img.size[1] - 1 - y)) != WHITE_PIXEL_VALUE:
                break
            num_white_pixels +=1
        if num_white_pixels == img.size[1]:
            pixels.append(None)
        else:
            pixels.append(num_white_pixels)
    
    # convert list to pandas to clean up distribution
    pixels = pd.Series(pixels)
    # interpolate to make distribution continuous
    pixels
    
    
    display(myimg)

# %%
drawing = r'''
   ____
  /    \
 /      \
/        \
'''
img = create_dist('', drawing)
for y in range(img.size[1]):
    img.getpixel((0, 249))
    img.
# Out:
# <PIL.Image.Image image mode=L size=500x250 at 0x7F8EEBA7B7F0>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-225-ddfda082bac1> in <module>
#       6 '''
#       7 img = create_dist('', drawing)
# ----> 8 for y in range(img.size[1]):
#       9     img.getpixel((0, 249))
#      10     img.size
#
# AttributeError: 'NoneType' object has no attribute 'size'

# %%
# %%imagine
#   ____
#  /    \
# /      \
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x7F8EE5B6D910>

# %%
# %%create_dist
#
# __ __ | \ / | | \/ | __ __
#       |     | |    |
#       |     | |    |
# Out:
# <PIL.Image.Image image mode=L size=500x250 at 0x7F8EE6CB47C0>

# %%
# scipy.signal window functions

# %%
from PIL import Image
myimg = Image.new("L", (200, 100))
myimg
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x7F8EE8769B80>

# %%
from PIL import ImageFont
ImageFont.FreeTypeFont("./cm-unicode-0.6.3a/cmunrm.otf")

# %%
myimg = Image.new("L", (200, 100))
myimg
# Out:
# <PIL.Image.Image image mode=L size=200x100 at 0x7F8EE95D5A90>

# %%
# Categorical Values
census.dtypes
#df.dtypes.value_counts()c\
count = census.dtypes.value_counts()
for i in count.index:  
    print('The number of ', i, 'objects is ', count[i])
# Out:
# The number of  int64 objects is  69
# The number of  float64 objects is  31

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df = pd.DataFrame({'mixed_data': ["John", "Jane", 123, 1.2, [1,2,3]]})
df['types'] = df.T.convert_dtypes().dtypes
print(df)
# Out:
#   mixed_data    types
# 0       John   string
# 1       Jane   string
# 2        123    Int64
# 3        1.2  float64
# 4  [1, 2, 3]   object

# %% [markdown]
# You can try to do a conversion for each type on to a new column and do additional procession from there? :)additional processing*

# %%
# pandas.core.window.Rolling.apply
